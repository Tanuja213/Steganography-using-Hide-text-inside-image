# %%
#import libraries
import cv2 #opencv
import numpy as np
import string
import os
import matplotlib.pyplot as plt

# %%
#ASCII CONVERSTION

d={chr(i):i for i in range(255)} #characeter to ascii
c={i:chr(i) for i in range(255)} #ascii to character

# %%
image_path="/content/veg.jpg"
x=cv2.imread(image_path)
xrbg = cv2.cvtColor(x,cv2.COLOR_BGR2RGB)
plt.imshow(xrbg)
plt.title("Original Image")
plt.axis("off")
plt.show()

# %%
x.shape
# Out:
# (225, 225, 3)

# %%
key="123"
text = "secret"

# %%
#ASCII Value

text_ascii=[d[ch]  for ch in text]  #list of ASCII values of text characters
key_ascii=[d[ch] for ch in key]    #list of ASCII values of key characters

print(text_ascii)
print(key_ascii)
# Out:
# [115, 101, 99, 114, 101, 116]
# [49, 50, 51]

# %%
#encyrpt using pixel modification

x_enc=x.copy()
n=0  #no of rows
m=0  #no of col
z=0  #color panel
l=len(text)
kl=0
for i in range(l):
       orig_val=x_enc[n,m,z]
       new_val=d[text[i]]^d[key[kl]]
       x_enc[n,m,z]=new_val
       print(f"Embedding '{text[i]}' (ASCII {d[text[i]]}) XOR '{key[kl]}' (ASCII {d[key[kl]]}) = {new_val} at pixel ({n},{m},{z}) [original={orig_val}]")
       n=n+1
       m=m+1
       z=(z+1)%3
       m=(m+1)%3
       kl=(kl+1)%len(key)
# Out:
# Embedding 's' (ASCII 115) XOR '1' (ASCII 49) = 66 at pixel (0,0,0) [original=121]
# Embedding 'e' (ASCII 101) XOR '2' (ASCII 50) = 87 at pixel (1,2,1) [original=140]
# Embedding 'c' (ASCII 99) XOR '3' (ASCII 51) = 80 at pixel (2,1,2) [original=156]
# Embedding 'r' (ASCII 114) XOR '1' (ASCII 49) = 67 at pixel (3,0,0) [original=119]
# Embedding 'e' (ASCII 101) XOR '2' (ASCII 50) = 87 at pixel (4,2,1) [original=136]
# Embedding 't' (ASCII 116) XOR '3' (ASCII 51) = 71 at pixel (5,1,2) [original=153]

# %%
cv2.imwrite("encrypt.jpg",x_enc)
# Out:
# True

# %%
plt.imshow(cv2.cvtColor(x_enc,cv2.COLOR_BGR2RGB))
plt.title("Encrypted_Image")
plt.axis("off")
plt.show()

# %%
#Decryption
n,m,z=0,0,0
kl=0
decrypt=""
for i in range(l):
    val=x_enc[n,m,z]
    orig_char=c[val^d[key[kl]]]
    decrypt=decrypt+orig_char
    print(f"Decrypting pixel ({n},{m},{z}):{val} XOR {d[key[kl]]} = {val ^ d[key[kl]]} -> '{orig_char}'")
    n=n+1
    m=m+1
    m=(m+1)%3
    z=(z+1)%3
    kl=(kl+1)%len(key)

print(decrypt)
# Out:
# Decrypting pixel (0,0,0):66 XOR 49 = 115 -> 's'
# Decrypting pixel (1,2,1):87 XOR 50 = 101 -> 'e'
# Decrypting pixel (2,1,2):80 XOR 51 = 99 -> 'c'
# Decrypting pixel (3,0,0):67 XOR 49 = 114 -> 'r'
# Decrypting pixel (4,2,1):87 XOR 50 = 101 -> 'e'
# Decrypting pixel (5,1,2):71 XOR 51 = 116 -> 't'
# secret
